# %%
b =float(input("Enter the base of a right angled triangle : "))
h =float(input("Enter the height of a right angled triangle : "))
area =0.5*b*h
print("Area of the right angled triangle : ",area)
# Out:
# Enter the base of a right angled triangle : 98
# Enter the height of a right angled triangle : 90
# Area of the right angled triangle :  4410.0
