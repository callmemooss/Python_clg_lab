# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
mark=int(input("Enter your mark:"))
print("Mark List")
print("Name:",name)
print("Age:",age)
print("Mark:",mark)
# Out:
# Enter your name:Navas
# Enter your age:22
# Enter your mark:25
# Mark List
# Name: Navas
# Age: 22
# Mark: 25
