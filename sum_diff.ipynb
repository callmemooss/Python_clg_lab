# %%
a=int(input("Enter a number:"))
b=int(input("Enter another number:"))
print("sum=",a+b)
print("diffrence=",a-b)
# Out:
# Enter a number:10
# Enter another number:5
# sum= 15
# diffrence= 5

# %%
a=int(input("Enter a number:"))
b=int(input("Enter another number:"))
c=a+b
d=a-b
print("sum=",c)
print("diffrence=",d)
