# %%
a=int(input("Enter a number:"))
if(a<0):
    print("The number is Negative: ")
elif(a==0):
    print("The number is Zero: ")
else:
    print("The number is Positive: ")
# Out:
# Enter a number:0
# The number is Zero:

# %%
a=int(input("Enter a number:"))
b=int(input("Enter another number:"))
c=int(input("Enter another number:"))
if(a>b and a>c):
    print(a,"is biggest")
elif(b>a and b>c):
    print(b, "is biggest")
else:
    print(c, "is biggest")
# Out:
# Enter a number:12
# Enter another number:22
# Enter another number:6
# 22 is biggest

# %%
a=int(input("Enter your age"))
if(a>=18):
    print("you are adult")
elif(a>13 and a<19):
    print("you are teenager")
else:
    print("you are child")
# Out:
# Enter your age18
# you are adult

# %%
a=int(input("Enter a number (1 to 7) "))
if(a==1):
    print("Sunday")
elif(a==2):
    print("Monday")
elif(a==3):
    print("Tuesday")
elif(a==4):
    print("Wednesday")
elif(a==5):
    print("thursday")
elif(a==6):
    print("Friday")
elif(a==7):
    print("Saturday")
else:
    print("Invalid Input")
# Out:
# Enter a number (1 to 7) 7
# Saturday

# %%
a=int(input("Enter a number (1 to 12) "))
if(a==1):
    print("January")
elif(a==2):
    print("February")
elif(a==3):
    print("March")
elif(a==4):
    print("April")
elif(a==5):
    print("May")
elif(a==6):
    print("June")
elif(a==7):
    print("July")
elif(a==8):
    print("Augest")
elif(a==9):
    print("September")
elif(a==10):
    print("October")
elif(a==11):
    print("Nuvember")
elif(a==12):
    print("december")
else:
    print("Invalid Input")
# Out:
# Enter a number (1 to 12) 12
# december

# %%
a=int(input("Enter a number:"))
if(a%3==0 and a%5==0):
    print(a," is divisible by 5 and divisible by 3 ")
elif(a%3==0):
    print(a," is divisible by 3")
elif(a%5==0):
    print(a," is divisible by 5  ")
else:
    print("Invalid Input")
# Out:
# Enter a number:30
# 30  is divisible by 5 and divisible by 3
