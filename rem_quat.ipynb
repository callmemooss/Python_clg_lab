# %%
a=int(input("Enter a Number:"))
b=int(input("Enter another number:"))
q=a/b
r=a%b
print("Quatient of the two number:",q)
print("Reminter of the two number:",r)
# Out:
# Enter a Number:20
# Enter another number:6
# Quatient of the two number: 3.3333333333333335
# Reminter of the two number: 2
